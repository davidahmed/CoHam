# %% [markdown]
# ## Original Data- this data can be obtained from the Blockchain after appropriate parsing.
#
#
# blockhash.txt -- enumeration of all blocks in the blockchain, 277443 rows, 4 columns:
#
#
#  	blockID -- id used in this database (0 -- 277442, continous)
#  	bhash -- block hash (identifier in the blockchain, 64 hex characters)
#  	btime -- creation time (from the blockchain)
#  	txs -- number of transactions
#
# txhash.txt -- transaction ID and hash pairs, 30048983 rows, 2 columns:
#
#
#  	txID -- id used in this database (0 -- 30048982, continous)
#  	txhash -- transaction hash used in the blockchain (64 hex characters)
#
# addresses.txt -- BitCoin address IDs, 24618959 rows, 2 columns:
#
#
#  	addrID -- id used in this database (0 -- 24618958, continous, the address with addrID == 0 is invalid /blank, not used/)
#  	addr -- string representation of the address (alphanumeric, maximum 35 characters; note that the IDs are NOT ordered by the addr in any way)
#
#
# ***
# tx.txt -- enumaration of all transactions, 30048983 rows, 4 columns:
#
#
#  	txID -- transaction ID (from the txhash.txt file)
#  	blockID -- block ID (from the blockhash.txt file)
#  	n_inputs -- number of inputs
#  	n_outputs -- number of outputs
#
# ***
# txin.txt -- list of all transaction inputs (sums sent by the users), 65714232 rows, 3 columns:
#
#
#  	txID -- transaction ID (from the txhash.txt file)
#  	addrID -- sending address (from the addresses.txt file)
#  	value -- sum in Satoshis (1e-8 BTC -- note that the value can be over 2^32, use 64-bit integers when parsing)
#
# ***
# txout.txt -- list of all transaction outputs (sums received by the users), 73738345 rows, 3 columns:
#
#
#  	txID -- transaction ID (from the txhash.txt file)
#  	addrID -- receiving address (from the addresses.txt file)
#  	value -- sum in Satoshis (1e-8 BTC -- note that the value can be over 2^32, use 64-bit integers when parsing)
#
# ***
# txtime.txt -- transaction timestamps (obtained from the blockchain.info site), 30048983 rows, 2 columns:
#
#
#  	txID -- transaction ID (from the txhash.txt file)
#  	unixtime -- unix timestamp (seconds since 1970-01-01)
# _______
#
#
# ## Computed data - this data is obtained from the above data
#
# contraction.txt -- list of addresses possibly belonging to the same user, 24618959 rows, 2 columns:
#
#
#  	addrID -- address ID (from the addresses.txt file)
#  	userID -- ID of identified user (not continuos, each two addrID which belong to the same "user" appear as inputs in the same transaction at least once)
#
# balances.txt -- balances of nodes after 277,443 blocks (on 2013.12.28.), 24617959 rows, 2 columns:
#
#
#  	addrID -- address ID (from the addresses.txt file)
#  	balance -- balance in Satoshis (1e-8 BTC -- note that the value can be over 2^32, use 64-bit integers when parsing)
#
# degree.txt -- node degrees (number of distinct transaction partners), 24575385, 3 columns:
#
#
#  	addrID -- address ID (from the addresses.txt file)
#  	indeg -- indegree (number of distinct addresses which appear as inputs in transactions where this address appears as output)
#  	outdeg -- outdegree (number of distinct addresses which appear as outputs in transactions where this address appears as input)
#
# txedge.txt -- edges constructed from the transactions: a transaction with 2 inputs and 3 outputs results in 6 edges (all possible combinations), an edge may appear multiple times, with the corresponding transaction IDs, 129178908 rows, 3 columns:
#
#
#  	txID -- transaction ID in which this edge appears
#  	addrin -- sending address
#  	addrout -- receiving address
#     blockID -- Block ID
#
# txedgeunique.txt -- edges constructed from the transactions; each edge appears only once, 89220163 rows, 2 columns:
#
#
#  	addrin -- sending address
#  	addrout -- receiving address

# %% [markdown]
# # Analyzing the Blockchain
# This study looks at the blockchain as it was at the end of year 2013, wherever possible, extra information has been provided

# %%
import time
import mmap
import pymongo
from pymongo import MongoClient


client = MongoClient()
client = MongoClient('localhost', 27017)

"""
this is our database which has following collections/tables/databases. For further description, 
match the names with the original dataset

'degree',
'addresses',
'addressCount',
'txout',
'txtime',
'blockhash',
'contraction',
'txedge',
'txin',
'txhash',
'tx'
"""

db = client.blockchain

"""
The database below is based on info we scraped from the blockchain.info webste. The number of total 
tags are 3557. Of which 3316 tags have been verified.
"""
db_meta = client.info

# %%
"""
We index the table based on entries we query. This makes the lookup almost as fast

For comparison, a lookup of a wallet address among 24.5 million addresses takes....
...0.001255 seconds, which is almost equal to in-memory python dict fetch. Yeah!!!
"""
#db.tx.create_index( "txID" )
#db.addresses.create_index( "addrID")
#db.txout.create_index("txID")
#db.txin.create_index("txID")
#db.txedge.create_index("txID")
#db.txedge.create_index("addrin")
#db.txtime.create_index("txID")
#db.txhash.create_index("txID")
#db.degree.create_index("addrID")
#db.contraction.create_index("userID")
#db.contraction.create_index("addrID")

# %% [markdown]
# ## How many addresses can we tag?
# In this notebook, we start with 3557 addresses, then we go on to tag clusters. We are interested in finding how many addresses (don't forget 24.6 mill) can we tag with just 3557 publically tagged addresses.
# Tagging is a crucial step, for instance, if we know one address belongs to a bad guy, then we find bunch of addresses belonging to that guy, and we tag them all with the individuals owenership. We'll later develop a very simple strategy to give risk rating to different addresses.

# %%
#Find the clusters with largest sizes.
documents = db.contraction.find()
addressCount = {}
for i in range(documents.count()):
    userID = documents.next()['userID']
    addressCount[userID] = addressCount.get(userID, 0) + 1

#There is no need to sort as shown below
sorted_addressCount = sorted(addressCount.items(), key=operator.itemgetter(1))

# %%
#Create a database of clusters.
posts = []
for each, another in sorted_addressCount:
    posts.append({'userID': each, 'addressCount': another})
    
#Bad idea: over use of memory
db.addressCount.insert_many(posts)

#db.addressCount.find().count()
#12137803- total clusters

# %%
#Meta info of addresses
#I had to do this to migrate the old database into the new one
#You might want to see how our meta-info database is set up with 
#future in mind.
posts = []
while cursor:
    post = cursor.next()
    posts.append({
        'address': post['address'][0],
        'meta_info': [{'info_source': 'blockchain_info_public',
                       'tag': post['tag'][0],
                       'ref_link': post['url_link'][0],
                       'verified': post['blockchain_info_verified']}]
    })

# %% [markdown]
# ### How many tags actually?
# Because we have tags 3557 tags collected this week, and our dataset is only until the end of 2013, we pick only the relevant tags - 1541 (shown below).

# %%
t = time.time()

cursor = db_meta.meta.find()
known_addresses = []

for entry in cursor:
    if db.addresses.find_one({'addr': entry['address']}):
        known_addresses.append(entry['address'])
        
print("{0} addresses tagged.".format(len(known_addresses)))
print("It took {0} seconds to carry out the above operations".format(time.time()-t))
# Out:
# 1541 addresses tagged.
# It took 1.8386666774749756 ms to carry out the above operations

# %%
# We obtained a list of bitcoin addresses and their tags above.
# Now we map those actual bitcoin addresses to our internal id representation.

t = time.time()

known_addresses_id = [db.addresses.find_one({'addr': x})['addrID'] for x in known_addresses]

print("It took {0} seconds to carry out the above operations".format(time.time()-t))
# Out:
# It took 0.7090697288513184 seconds to carry out the above operations

# %%
#Let's connected our internal ids[tagged above] to our clusters

t = time.time()

known_addresses_cluster_id = [(x, db.contraction.find_one({'addrID': x})['userID']) for x in known_addresses_id]

print("It took {0} seconds to carry out the above operation".format(time.time()-t))

#This is not necessary, I did it for my own analysis.
known_addresses_cluster_id.sort(key=lambda x: x[1])
# Out:
# It took 0.7048068046569824 seconds to carry out the above operation

# %%
# Now the fun part.

"""
We do a single round reverse lookup. That is, we pick an address, find its matching cluster.
Because our original hypothesis was that our clustering was done based on the
owner of the addresses. Also, because we know the tag for one (or more) addresses belonging
to a cluster, we can tag all the addresses belonging to that cluster. 
Let's see what we get. 
"""

# %%
# Let's find a representative address of a cluster i.e. one address per cluster.
cluster_with_one_address = [(cluster, addrID) for addrID, cluster in known_addresses_cluster_id]
seen = []
cluster_representative_addrID = []
for each in cluster_with_one_address:
    if each[0] not in seen:
        cluster_representative_addrID.append((each[0],each[1]))
        seen.append(each[0])
        
len(cluster_representative_addrID)
# Out:
# 792

# %%
total_tagged = []
for each in cluster_representative_addrID:
    for each in db.contraction.find({'userID': each[0]}):
        total_tagged.append((each['addrID'], each['userID']))
len(total_tagged)
# Out:
# 1625753

# %% [markdown]
# ### We tagged 1625753 individual address with just 792 relevant tags!!!

# %%
#Let's do some verification.

# address: 14Fu4z4EBmX8Lq7H3whG9bUJFLAdBDEevY belongs to JustDice.com
# But how many other addresses belong to JustDice.com?

JustDice_com = db.addresses.find_one({'addr': "14Fu4z4EBmX8Lq7H3whG9bUJFLAdBDEevY"})['addrID']

# %%
#Here's the cluster of JustDice_com
for each in total_tagged:
    if each[0] == JustDice_com:
        print(each)
        break

#Output: (13757387, 1911)
#Let's see all the addresses of JustDice_com
Just_Dice_com_addresses = []
for each in total_tagged:
    if each[1] == 1911: #same cluster
        Just_Dice_com_addresses.append(each[0])
# Out:
# (13757387, 1911)

# %%
# len(Just_Dice_com_addresses) is 970. i.e Just_Dice according to us, used 970 addresses.
# We can print all the addresses as follow:
for each in Just_Dice_com_addresses:
    print(db.addresses.find_one({'addrID': each})['addr'])
# Out:
# 112FvcGnLE4AdwqyvKuMvc59rouW4pKRqE
# 11yXpzJqK4ayzVMpDaYJK7uYg5JAmZu4g
# 121ZeKphw2vYZZcy3kzhBdmazCqrZPcGDM
# 123H9hxPHcLmJmKTvP9NhUot6jkSoC4McM
# 12EHcqmkwfxkpucpGNAT6VhLnfaqdjcmou
# 12freeXkmFTfpzwnXjVriabnqH1FKyuy37
# 12ioadrTbWfjinefvY4dKGb6XhqRZWk3an
# 12jAGBkhvLD7PjE1RTWuxEBDVNn2buBQUu
# 12PehiGXQZSNVREXb3RM9ttrSsqVGCMZe1
# 12pj5HDHSqZ1eYBDZ3umDNBr2SnWDP5iER
# 12x21Uhbsd62Moiak1jbdTqF88fywgBaza
# 12Z6FwkMCNGQFaND9UDp1SbLTA2m43PhPd
# 132zc3fdxEXLuvArESq4Xsgc1oQaELKFiD
# 1337Meig7HhQK6MSJRH9SnoMrKmbmptSty
# 135foGiyDt5qEk6qC9NcsdHCf3RuybJaLg
# 138vkjSzqbXcSdjZcVHC5B5uueMr1VQVwH
# 13DCKMNrvrw23JJeC4sarwoZy5wGuLWPgJ
# 13GvYiQQxQWytc3Y6ogmXofm3K9DjXkDMm
# 13htmWm2vESARLQRBAZEXcJKa7rsNqPrxU
# 13SYtpTeNpsLzPZoHdNHpX5ViPpFnDLkeK
# 13xASha5saJ3T2HrxZ4MMgrNwvCnnH5pNV
# 149eLCZNnUsQKQL8Doc7AWr4noL7KD1vBW
# 14CPi1pKVdUozaDdb6zZXgP8f1JukN9yG9
# 14FNfmsCLT4kVo7NzPfEhvNWb1G3xeFsrc
# 14G6rsP2UCgKayBBKirMr1j2TCn5bfVLFr
# 14hHUqMroCKmRjZA8ygcsUeSKdAbSutWnH
# 14iAg9iu2oebfFSQSHeuCm5eQCHDfSXRhy
# 14mE14uXVX2s7a8nBhgK1NHpLpoFCP9YwQ
# 14o268WyZQvV82Pt6J4KJ11QiydDKgpWdP
# 14Qabdf4ciP5UWcSNSgeNHuTncFUBzcvxc
# 14qbRwvMASGosCD2h5DfWt6rpf87s9WP2G
# 14QekxUfwF9eJfjrFAsLzHARjamzTV3f8W
# 14teX6HEKMSVpbsFxU8XAzYkHq8sVr3c2n
# 14TJoXWySjNZW2YCKLNGdAGVdgnCHKf8v9
# 14tjus7PVaoY7drim7wr6riHquVQ3GxfHe
# 14X24a9uJgpcwACyxJmUG7rTvvmijVHhwg
# 152TWfuSw1abHb6ZroXVpaYju37Ct12rsA
# 15duCtsR1Wpg4oBVqkS8HxYYgmERg6pFrH
# 15FSqSdgX3AzuZsVRApRWUf4nYqE3PosQs
# 15gHxiQxhHXNJAY9Bat6unZB6NYVqx3J5t
# 15KeBXt2bs1Rs7tSFmv9UfxSrcQH569zw6
# 15P7xojrbYvHsW4veRqq5Y2PmSVNXSbexC
# 15PuyDjjE7ZwpBgVR827nHkWgbA8gHJdtG
# 166UA5SsEUmRhrqpJvbN12DBaeQBDFWDjd
# 16b2tiUwJLAG3zbP1vQRYYhPkSqexBMQB4
# 16dn62SQkfM1kBzspDAmg8hYbHb8gL6Juu
# 16mB652v14DBEMvrAWeLXsh9G8mgwawc1q
# 16qvxpFmMohrxduYbyJmAUt9sRmTF7jt1H
# 16S4qog86fLmt6S6nD3Tz47ceq659sdMDS
# 16whn7fbmPdyPh3CqCCvi4EvPr5ZEcV3N2
# 16Y93SPA2E7UJ2XyBLjdpeXkvCaZmb1HKo
# 173x4x9XPNHv11CC6ygYoihrr41p98ANgt
# 17BgnL9PBYecU6KegDXfJY628dnheD8Nkb
# 17CW79UE6JTZQDZXE6BtMT8HVoYviQRXLX
# 17M1Kpg1NVzx7qaowBukmn9jfEveE8USZk
# 17ombmY1myLvWUsnmEhyeFbtooZWtJfyfA
# 17rV2afkoaMxgRAnYYwW8J1gNLKS8HLBU9
# 184pNRhzuMhqcoh9bqyvzsrr2vSUt18o9N
# 187rJu4xCbwQFGbxg38UG5qeT2PzK25mSw
# 18ANXrHeADB8FxbsgaMBPuPC2DjZN5Bfj3
# 18CGrwf5EaADbAbw3jQRaTFaWD1DaNNrWN
# 18HxeqqLvHsiXZRtG64bkUKUfW3ogGRWY9
# 18KewJgchNWMXZuzSJZEBUmbU4tCYMKnnP
# 18kwYx7d9o4zAshUGSTVq3DNq1cwZFxUmA
# 18NhiCU682KMcKGpeotfq29eyevCewySmk
# 18QV41dLtGjji2TpcJNcAu6Dc5LmSFUgh7
# 18Xr3p2iGYECYcQw9gDV6cw6uhZekWoyZV
# 191x7AJ12itADrANzx7UVvK7xJpmvmfjyf
# 193VhY392zhejJR34C4y6XgUAzTkSPxAGH
# 197MEfpaAC49cHjv1p9ufFAF7PKzwtk56y
# 19GDAqXrCZA8mAaTMdbbeAcPSxVRtZUavW
# 19JqEDwnpvF7VsgqWeKDNDCeWN4NHrUwcL
# 1AdopT9bVxKSLxUD3CHKj9HgNP2Cwb64qt
# 1Afcjd9w345MRUG2Kufm9aUrKik52s66Gh
# 1An1anENhdPZgD7ffAvT5uzCLjgkSythBZ
# 1AtLb99v5tKXFokHwL4dvwp8HQiEhZXjSG
# 1aY1N1cCjgm31SLGp2rvavUu5j7CYvFjW
# 1Ays7JfjfTEoyzvvZpHX5yHDjtCg8dVW9Y
# 1B1ahr8sQNGN8ZTS4mDRhUYofHVHCxhsyk
# 1B3jSk6y4HGiV1F27bhNcsbSmdcreMkjGF
# 1B4o8RoGnxgLD4yYZnmLs9kNH4kV941QQf
# 1B819kqVWkyNiq3xqbZiKc3E1EhruygwHP
# 1B87XPbvPAUaJVZNuhhoZ22Lt3Duv2HQ6f
# 1BAE2yjmZcSaAH3R9hEdk2aHLAtPc2wpTe
# 1BbLT1fAEvEMMMW2hn4a7pi4qfYQAMHNX5
# 1BEASTQk6WdPAhbrvAR4pvUNhmct1oJwHw
# 1BeErSojtb4TJdfZmXTweLTKYzeBAdRyJd
# 1BMoBpFpKqUfLUxPmwsy7g4y42iCvqCzNV
# 1BN5y21XaHGLqRKxQygjsfC9Hi9sfetreY
# 1BooBz2AEwUd6JepB7NhNsnAe58Q6obpcu
# 1BPEDfLj9DcJUKwU3gffU8FjF3nwp3su5o
# 1BUMpoUmQARRAoYAWTwDUUA6DEEXXwXDMW
# 1ByEAYpQybAGguCNwiwu7M3cbdkQiV2BWJ
# 1C26LkkwjYSBgLDrzJNcA5q6yWh2cPW7bJ
# 1CanuCkr5gxWDN8LDjpCH3E9wAa9ibsaf9
# 1CarTEanHQ7RhFzB3FhtzMdkXsnLXGSAMV
# 1CdKGSJuLN3VKS3oA1sqcXiWwJKCxLvwtE
# 1CEnTSpN6qiLforks6jsrr5jdRzWS7eUUv
# 1CheSTzHqFfC3KFaHpxvP6iXy7NLYC7ARG
# 1CHrisM4AtATqAdnf9pkahpSZSWnE9dMSg
# 1ChugsbhoGfG5gkAQP9qaB4Qqh36RthSsT
# 1CJyF4HKbViDM5Cj7TjsgWB4bftZncEVMk
# 1Court1JkDL29FZiwnAQR3XQ2xjVS1mZPW
# 1CR7oiWLwPLfGX6qgp89Gvb4o7MMH9D32a
# 1CRAbSv7EhVv6zsmR8f8kaRYZvRL3CHBP5
# 1CugFVqdFWFGNQMSBZ8mUuG3xMYD1KyoLG
# 1DERfULkLu269Dp3V9rqkTvb3BFe4PkvVk
# 1DhUinqsxPij3ftbaPe2BeiqK2EevMmfL
# 1Doog7asLrYah3yeUppBVj8nUYnFkmXm2N
# 1DoogYca1LGKP9V9cQhsxhMAhKyAFhCzRw
# 1DorkSNgXDvjjJWeNvVyMnHQrKz8ioY9i5
# 1Drousy6gGuZ8CqD3zPmUbUJu8gwG5AgYF
# 1DUMb1toLXLTDo3QcvtJPqD642YyzPE9kA
# 1DVEak5a6WbzXqZM2ruVwmTyvjYWAHj7gs
# 1DVLLzXETL2FKFq65t66NmVGhkKJTy5zsq
# 1DwEEB9oAiywEub9rprBWNkLGq4phmB9B8
# 1dYJs2XjoPE8Wi7QgeGHjK1UrisXbLybT
# 1E2eJ6DmbpMEwisXy5Zh3mXWJ3JUJc3WEL
# 1E2qgikuqh2pi1YZPb75Q63pNfYXc8ATmi
# 1EAQZw6rSJuyq9mcSHo61DUujjrxLkhLrR
# 1EAtMeP7dgj8vofYkmEdbLjfeLHHWa6cHG
# 1Ed62ZfuPzT9jeD4ZtbaiFtKVUsoD34JoD
# 1Ej1pLHTB7Gf3Q3VASaqo3TxEAJ3U7ejcn
# 1EJect68KjE4tPicEuqEr2MzCJFMzFQrtQ
# 1Esc7fRRn6juX3H9s6vytaGk9i4h1GLRDo
# 1Eu2SMF3EjyqsRs9zgHhryLoQ8gJ83mH8X
# 1EURoSHupQudUh5fKAB6iMDyRH19KfHZZK
# 1ExAmSB4zeFRTFZxQFqWnArHZS36UZpC4u
# 1ExTraMrvJsNxeutYD3SBifSGMZFqkCE2m
# 1EzAy8Jf8x454YrVyQJTVRPf9PnuuXcQ8z
# 1F2yYNXKW1tHJ3fFDmqqKGC25SPxnxXNtn
# 1FAct8vvC8zcRhtGYRhqceE9e1hWtUUw5r
# 1Faith25BGRnKj6rHtmm3kYtmVXPBwM35H
# 1FaKeD9xEcTu63orxvWMsHnEx4z7ierEsW
# 1FCoingDChHSWZS5w5uUaUpH3mfueWB117
# 1FishyhUggVt4Yrd9nWZzUnAMwB7iiKi4a
# 1FLaMe8wNfmxG2fic5in9WzutqM2NyUUfy
# 1FLipSqGsvFTiS4cBLY1NLHsUEkc2iRQL2
# 1FoaMyL768Ldg6PUtyEqy8Ln1gKM11nD4k
# 1FULLwP2dFPuWQv47EfWAuWvaSUTkTyBev
# 1FunnY1xtRZ4dGJVb4NsdkG4w8SXnHBqYT
# 1G33K4uZz38WqGDGR4QrZQrqxqifNbGRHA
# 1G5aHMYZ4jy7rAiT9vvSRLxeSTSqtQhBhg
# 1GALaxyYHnE1NFtz6yijLm7jf7kuCH2mXv
# 1Gco4AEocPnhXmADcHvUfimjTphURVYQMF
# 1Grtoj1EBqj1cLdGGGXnUKk4tRHHqDExxL
# 1GUcT1pjZLvt962hSSmmMmdEk5uAsDDae2
# 1GvYUWtZmXU8k9uSA48Keh2fPNptUJ7iEt
# 1GYPpeRnhjxqhdkcDnv3yzbYx9ZWvdDHT3
# 1GYPPyQc8ufoJCKzJozH88ZFCH3eXT9j5A
# 1GyWRbeFT8VMtNzkcitubPQLwbpVy28CpC
# 1GZE92GdUsfZSJtUfXm4ojEDu841oTVAA
# 1HaYftzboccj4Kbw1MSE9FtRskanZpV7Gs
# 1HCN1vR8DAUpuSSC4RrKkc2UiJtuyw6aUc
# 1Hirerfj8itBhht4nsZ2xBqqezKkFn15iq
# 1HK8YNFT9BMmLZxhDVAs4LpbfJrTkha17k
# 1Hp5RTfdtFpzeGgiR87rqtwYnw8y5nPJGm
# 1HXkKj2fMR6NefQevSSQW3xrziM1yeCfbb
# 1Hxuw3Ztt8v8BjAf5zfpvs6dFFd2k1se4T
# 1JAd13vNuuYpGdiUJ3vQYMfa49mYizdsmz
# 1JErKs4SU2JfqK8k3Tot9XxV6vdbzoMvh7
# 1JimPyq7k9hZDs1jUDm9h9mfxgotR5TyDa
# 1JiSmswDRk1eZqAwm4pwa518AEWiYbiyeo
# 1K2NenM49q18V6yLyYaFB4WJMMj1pibALM
# 1K3wkuSCauhAwb4iJ4DyqRCdXJz857fi2t
# 1K9eCdaRuTdgAGFZGfjFcYnNGd4RUb7V55
# 1KinkYiVnzHVNAh1gXG12dDPJB1Aky2Dfo
# 1KLDf7aGjenrvgWDvQadVZM5xXZXWkUGiQ
# 1KV17mk58bHxZiAMroSiKg8k4hzg9ARAHQ
# 1KZc8Xd3yjshc8EM89AqAsJBKxv2eTb4WZ
# 1LbJAm5YPsHV4QWC5A88yK4jMbQUWENS6W
# 1LCYwMpz1TDKQcjw7fApJCDpve7xPnYDJj
# 1Loves29Pz9Tai4KR7v4bcwAR7dFnoSkze
# 1LpRCxCzpDq5gT5nYVSTrwmSg6DU7DbrCg
# 1LvN9yCBv6iJ5gmY3KhbNJYDMKuH5XaS4z
# 1LWn4RP2Y526uGd2NdX3NFLfPASAJybJo9
# 1M188XxDESY3mSUkBTzSnnCAQikYci3UQA
# 1MHXS4cKPUoxPXkqA93XuP5iWRbtupPwUY
# 1MjnToLHprEkhuRatiT5KeFaNEf2m9Q7jb
# 1MMWZ2bucCPX3Wzr8Q5yYweDtpVoChGjsB
# 1MYPXqae9rk8oxJUD8QThSKyaKkrLAFYop
# 1MZ63no6nu7vL1zsEWAWnwRLP652wWRr3Q
# 1N3gD4i9xPoKHvnYEMojRJFPHo7EK1pboS
# 1Na6HoCwSsZ2kL6M1hYBwSSPjs7NUXFZSc
# 1NaMEd1jJWfLWVMjg34ZRfPhjYS2wDRpa9
# 1NeXT2uxX4wazr4a7ybJsaznEchazddYev
# 1NPBdxKMxaEpZ7mgXFeSY4u7wET1GphHiN
# 1NPyKKEibUUCSvCr4Nr6rDgeYajAv8CyWS
# 1Nrh9VvNXquvsfyGzsFmRzMyMgQHtQUEBX
# 1Nwiwi4bgDgArwkaJG5nQV5po5nNjDETih
# 1oFhCTnZHRpmaXAWfh35VkH5BpiYoqVDC
# 1oKbGpubYT1wj9hHDrJfN4zyJuBrngyhg
# 1P1kpj1vAcKUkQeG7nBbyMw88rT2ahzLRv
# 1P7DjLyjFS6pMxJHBGDCacBTUkBUfk9ofx
# 1PintssqDpQuDuVdycoTQiGYqvNur1DLuz
# 1PornoTv7yW8oi3vqL2bBXRX4f5tvWro83
# 1PrATS6RHM8DFx9rxNJQHzA8wFhXUekTf8
# 1PRRKnzCrF7XZAjupWfrg1jNnovVrdbfn5
# 1PsACmccnGAYT9ee19SCFZHibQ98Z4HcNw
# 1PUPiLeNKJX9BSGRH4NVPxiWTGyAnVeYqm
# 1PwgycpEn4G2Tb8wVNgMrhACukXLfvYsRf
# 1PwncQYDQDUAhrr2Ag5cTj3QNurMc3kWJu
# 1Q5JHEFYWhq1G9K5mUQieQXFyWU2pMBehr
# 1QRkKSA2WQwDffCMF9YGS1NhJWkHBs5M9
# 1Up2upZ1xo4tBoq86GLYywwRmshzJc7tA
# 1UTip8SzMy6j3AagRs46UxaR6ToNt58iT
# 1Wow1FrDwE8M7BwJ3FX68GPotfXVfCMoh
# 1XXjcfwXpyV78Fh7eYS2JUVf4WxaKLkvj
# 1Zwax195NWtixqv6jwZhtTC9RH7RT7481
# 115TvTVASyPCwEzA6pQM6rCQGwQRDi63Zk
# 12jYHS78MhjwYDnnFQEReUSaWgrcaJw2Jq
# 12jzfNmGuFYxG5fzs3QpM17jRaJH7qv7LX
# 12Kw3n8z6MAZEPVnFwvYYkTfr6zrUJKPPo
# 12MZFF9rhQRwgaB9AZ3xWNGcX3B2kMu2Nh
# 12ZjgiLM7Z2hFCRZtu4kFGvwPXJjQ8WtiU
# 134RF3n9WU6gd1MDVHGFmsRGzrBxLvBu4y
# 13EXRYKDKvwBAydzhwQTU4CGpU2EEKbJfU
# 13jLxQHwzb77PkWJKGEQXA7zrqHjVyukTd
# 13LeB4Zzn4Tg16pLbXS79oGAQrR2VdJG1s
# 13MqgaGPX2bx4i84rJUXyaWj8UVewu7ZuH
# 13PLH34tGfv13jLCkpyHScg1CWpGU4VFZ1
# 13tECjciPLumzWrF5GDXvTradLtrsTXnCQ
# 13w2bKBztZh2tCLJhz8oQM1NbtDdaZSaAW
# 13ySSp7jK1jYtGKegLc9vYDUCqt2bsTXad
# 142N5cgwx5huMFTjVWWMyDBgerSjK87eWx
# 142XVyP2a27CAeiaYedcnno7vEjPP58mad
# 14brpG4VBU6B5BFQukgEJPkdCdTRsSoBgy
# 14EvHPVP3KaoaQ32q93nmaFFH5d3Xwbsqd
# 14k77stgjuf6sjMgTH87zPhP6QJFrFLvbY
# 14s2iso3NMXc5DT5phfME37bnA2mEiXTZ2
# 153LvfdT5VYJasSycBzLBx15xkWLCA44pF
# 158AnMLCPaN4FTfdhcyrFhfRYBXbhHKEfn
# 15ASYzKqRh1ED3kQ8ndPvGucNStM1zuVn2
# 15esvRhrWuBSK7c7FomJSrnDncyBfVYTdQ
# 15gWnyhKiVPrEoHWmuqptKBCy836FG4wod
# 15khdp8RBf871MyVw6kaYpqxytkybyVAHB
# 15KLECpHiaqiHPpTZV4aT8H8iEUto4Xkvq
# 15t66VjMW5BKtFtJix3vxymuYJgEndfcC4
# 15tzejy6ipgu5qZBhMSKmkCCBRPgSUroSt
# 15XTFtHDBePX6ABo4KgwtWp1Yx5bLbToyC
# 16A8w3yb3jCiUfVgGJVVWWRcFtqU4whbFB
# 16aEdqh1XsBtkXX3X9i51JSnr5ZLoBP9Ec
# 16hMDPBkS5Hk671E9QPs4YPUuWC9KG7AqG
# 16HWxi7dmudjyPHc3wwMDx91Wr1pqtz11K
# 16NTguXRP4DTb4s6J1nPDp6ruNAUNebian
# 16yiKoi14oezaLkVPNd2Lq6pMRE6yCQEsF
# 172dB6EnE1d4n1f26VxdFoVNHV6xnMGSC3
# 17c1crbzESEwnDLx55J5YazUJ7axqMpgvM
# 17JdMM1drq3omVq1rZHHvtrBc4xKG9ztrH
# 17kKWBVu4bgUBZZJAP4nJ92nK5orH6Bere
# 17NKqaYwvs6qZuy3NyBAMYRCSny4muh37E
# 17qk1gBn1RumDLe6z1Y1jLQWrppwnnfysN
# 17R9THtyN34pcx1MwQrKVwHbKsWGrZeFcZ
# 17rcMiwekiVSyVVBWQ3iZTXP9yqeNsKBie
# 17SKqcrn7cU54X1R8gs9o9fmjtCCFjmxf1
# 18AfVbmGrr5frr7heS6T6EYV9FYfkpbNo1
# 18FgsU5tUVBW1Wy5H8dupyVu3MBJzmoxfs
# 18NfqSWaMKoDbpCFoa2UCiwwiUbic1P8gT
# 18QxJn36rVGmNdSt5Cu8ZGAzaC6NPgMUYd
# 18y6pF4w9JqD5sZ8qbnacPqgGc6ZmtfLk9
# 18YZemmHUjUv7LDq7rkPnD4Hgn6B3YmWMm
# 194mDXMptUE36aL9TmpRtEgJjWcDxfv3Ck
# 195BVaUcqsrpLjfUftY4EQwzwY8Tbng5m3
# 19akimqnfvoYK1kBJJU3tmMuYpbCFfpo19
# 19EynHXCViX4fpaqiq7uHFid32dZ16dfg9
# 19kH7TCtnkDwU5qsYK3riv5BXcknb2W9kr
# 19ohQZMgTQ7d2yYv1YnUS1efAW6Gf5JXxc
# 19pK6Xvri7kd5vkH9eGuX6Eecr9bzou3ha
# 19uBVB1ASxJuQTLKQwrLVSmYZoYqp4ciVs
# 19xypy6GJk5FyhaXoeYK7o1rVi44F81eX9
# 1AcK8nTZqEVRps8k1sNXuGsmb2SvqXTU62
# 1AHaHuXWioCgYtvXvaLoSU1k86sMdr4TLr
# 1An5LnhVQQ9mfPXJVY6AqkpKa6rdUTMHmC
# 1Ao31kSm9iG99MypDWM7ByvR8EhVYLgVGJ
# 1ApKxRHBGfofdJmZkJ628U2NGGCQttHbqg
# 1ApMsqv4g7NGCXxdiGArDj85dvY8p9BYUR
# 1AqHdccuMntgiCd4qwoj8CJ8rdEnYSAXvq
# 1ATu3RCgkp7MziZqhoMQsjzeGukqkdK6n4
# 1B1is1hbR7T4CqvNJe4Lsp9txYG9LgsTGF
# 1B1YKf3qACBT54yo2VPSZ4T1XSqkGdDTcb
# 1Bu3v9qtMAB54o9vW8Psz1ZAEkVFdAHH7f
# 1BViNR2r1T33PdQRPhLdgngX95wTieBkK5
# 1BXkieyjYM1hFHVcYavSrQhW4KXCoGXXG2
# 1BZCSjX3yETb4CexFccNTPjgMsY7mML7dz
# 1C7KGqVusFs9Yp8bzDVHQiLtP8tQneqzow
# 1C7P6jD4e5AGvYXCvCN1XCnSwshJt7J9is
# 1CJdWAXETGH2J7h9GsP88YyzymyNPWQisj
# 1CuoUKqFPQr4z1uHY2iz6VhMqFYT9ejmL6
# 1D6s8CdYtpThwga141yxZnExokUqkBUWbT
# 1DAy3dKwWyQMeUVNqed3WHgqtiSa6YfcX1
# 1DJs2LbU7GKUtF5SDoZX6kr4Sk3mVRk3A6
# 1DKcixrdTj3pQAEmx1C3omLx9VGakJ5EmX
# 1DPtqLPBcA7AZxQCspiZJsVGksFsyzFTt4
# 1DtuqF57GxMnSdNuxYWnMp944XmWp672XH
# 1Dv3VdEknZve5yqDTbuhKYJd1UcLo4E2SC
# 1DZhAnANrqFXNuQkDDoDmz463qAqFADng8
# 1E6PzJ6vrBLPFfgNDjgesgJLt3CpWa5jhe
# 1E7yF4tGJGfiLmbqbshpD18yFNapT5bWnW
# 1EJJHJcDTeYkcmY18meWJVxCEjsvdnXyTF
# 1EKLiPeEjBSxH5JE53Gs7tAT53sHn3y6dr
# 1ENhPicE9pA79aXVacrZBzLjWRv4e7MTNr
# 1ErHSVAVP668Rk8r2UPjetznX5PYKiR4EM
# 1ETE3tW2pgpDzzExj1jEyEDCKFnL8922Gy
# 1Ewpa1ZxRUsAgFgKB8bGTTCvzYG2gaowGT
# 1EzPVc45iYFMsxJdX1cZfJqPtokHm16tPy
# 1FeCgKT2tNzFzhqYGQD3v6qbVuZAKQs8Dm
# 1FGbBodnG3zndGFCuu2yMyhcTWRTyvDJ5k
# 1FLHbRqWbWbPTMqToeXCXGUkemb2uAgAKs
# 1FwDRMqhZFgtZNvRw1RC4K6UjVZ2mpSkca
# 1FWX9s361r2FyKUsyiPjTyahYfUjE3na9r
# 1G9RdZ5irZyFfT8XeR6Zaki64ac59aDTx8
# 1GdHhnhjDoSF5cm5mGi8dbRFfEbTVhb7Zs
# 1GEdXrcgSKGrmouPcz7U44ZzM9oAw6UMJZ
# 1GeFW3k9MXKLuo9ssVCF1vFAVzRhKbgqAq
# 1GeJcKRXuCvF2K9veAkBYqRjNGmA1m76sR
# 1GfTHgsvjUKtp6kVECF4do3oE5fE6Dth6k
# 1GFv7FPC9i98417KwQTFPYGHMVGsSAJp9K
# 1GjTGYkzQt4BQegQ4dux5rfjN5KQCJfD1h
# 1GkrDTs4vguraT9Eu84MViotaR9Le6Gy6U
# 1GQMi88wvf2b87P9xYeKmp4jAquEyCtqQn
# 1H66m2hFHAa33c9AkDUagB4x4SFiYmSGkH
# 1HbLv8Y9EvcSjcKWgpSLVPcroc6fWtkfeN
# 1HDTYYPx629pCnJYMrpD41NB85ub4MSdRw
# 1Hf7myW4VqQ6U8SzDuucqDdusgiskg7pNV
# 1HgkAsSzzuy8yRh62RharpT4jvPcjkQBry
# 1HR98ReuGqLsgrUS6QRMC6kYXVKoF7FDHz
# 1HuBpemHphMyk5GQ9ukDD5CJPTDiER7NVY
# 1HutWDSo3w3TkHr12az7dELTm9NK4rBiUM
# 1Hvu8b8UfcqHrXu38vZtifiRHoBxjFcGgT
# 1HwTx713NBGp63J4b4hHRGURJpJ2oKkyCW
# 1J7SLXDJmjDrdTD7WjFytymNpzn623sNiN
# 1JdzBuFiGKtamnwfBKmpJ2GoqfwQemi2gA
# 1JFGrTv4wobipJDh3BCgTGnk8DhjGDNxZc
# 1JfpJ1AvJufpSWi6wNfA8LHW21ztsPDheV
# 1JH3bcqCuZGeyXj8RWtFgn2MPZy1Ys3xNN
# 1JJFiYySGbsYz3rmC5PepBnW4kbUvo7hkG
# 1JnmFitkzDygzX9DYUHFVBT8jQtnETJma
# 1Jr2F4B39z1gkjZtWNuspwSHuqQPVki3q6
# 1K4aBd5e6jzaqFfRE76TzZGgrwPPVtProG
# 1K4m51cNLYzrHJwf3y99351hEM4Hyv6zoM
# 1K4xC7et5hwGLGppaEJwgq1kZLTWL2PT2J
# 1KgfRwgXLkPpTm5149QtS5fXi215QwbyCr
# 1KGnoMGEJPF4Aa4HRVkRdpKintfdq5q8je
# 1Kk3bQHBVLxUoBFxHb8S1GJfAfcoDZ1yPe
# 1KR3tJFkMSXNacJ1h6FJdaoJXQttE8uZaK
# 1KT7CSK2wARiqAECNsCXNFcbbt1RXHVbtN
# 1KvHzMVo2kVAv9BXCWfMXBk6Q6f8zk533S
# 1KzWySzgBueoRczqEJNzza5NvrjxKphf2V
# 1L1eig7hU7J5mtoEeHHrmi6pBisSuSC73L
# 1Lank6eALYjNKN57we7pEEZXzsJoLpsyzt
# 1LfGjowYU6xkcqjRwfXcn7zp6QLDiJbzdZ
# 1LhaFJgsK79N4S9CzyEFRAKgN8T6gqy5a4
# 1Lo89kz4yapcHRSPtaZXhrfnAoxp7jqddP
# 1Lra3kSJonQtCtmUKQEZGEQjhWr5mWAQF
# 1LRs3X8Yr1Gj9Ztz3h4U6cqGAyMERGXJ4s
# 1LWEnv19xnnjj3gxES34QGjD9nGdK2nPdx
# 1LWrmt4vk5zV3SonxyVBBomDyqMjh18CH8
# 1Lxcr5haVj95SAszQhGEbe9t97Bkzrk1qw
# 1LYP9x9hqFsD3e3H2S4kpLYKbmGUJNeyLJ
# 1ManFqfWN4gArVArVhjbDEY7Y7zVmhKiym
# 1MaYcZqysTZ3nfgsUkWPmAc5yx5TP8SVc9
# 1MAZ4Th4Swewkem9bRhFP47gPnWjPoA81Z
# 1MgKQ5EFTXPjupUBj5GLXqTv5S9dYuetC9
# 1Mh9r9PqdnmyKzuc8DUKSMHM3jgmP5QMoD
# 1MHdkVtEwJhmuy7CjzbMpexg5o5GL48uVY
# 1MioHXQraQijdE2q2TYUBEDjDkz79KKwSf
# 1MkDYSLVBbjg5K7UTkPVJ6NLC1DnRHALXv
# 1MVaE79fB697VS5o35Qtu1Vr9ymYuJ3knz
# 1MWh3fuwPCPL25LrRsvHibCKpgSdzvpts5
# 1MYwt8HGwCHc6z4o6uVWR5sLC6byue44Ue
# 1NfoW7XrTKm7kSPJcmMfGS47GkrEHoPeuh
# 1NggNiUWuJAxFWTLyAjBRYqisFhDt7RqA9
# 1NkTbgyA52X3Vn6URgeQuHqvKdN4qRE235
# 1NKV9BezTWHXjdgZen5MDFWoNTa6XAAmzG
# 1NPfADvzknHkFPMDpmMdsFRbtosvzyyJ55
# 1NTuhpxzhsB8E3jN9i6Es4ULEsAE239Vh8
# 1NwSMeaSqUqFEes6rDiQkFd5K5dzUbgf9a
# 1o1Xbjndv3gz464VzVctoH5GQ5cnweNT3
# 1onhUQXJp2yeoMtdREBtWFJygLVToiZXV
# 1PArUuxkEXYkhRBDaAU2c4w4Ff2X9Qvvkp
# 1PjULKiFVD4xtF1W5A4KDf9uCLRWh8Kwg1
# 1Pn7zu1rADvmWoFm5vyYt7SJaFcKwyGyNA
# 1Pp7qoQbwisP6hqmmmeb46rthCqNQdSr1K
# 1PpnPMDZunmJ2m7Qh2ozT47bfkk8Afza8T
# 1PYrMjDkJP369rm8vJMJ7GvZjS9YhY31fz
# 1Q3AZ2oHKv2cSP9pVd4xBcypBGpn6TPvMM
# 1Q9jbMXQiNR1t9jH4osjGfWRCVYrZE6kKf
# 1QAGiDMy8JkRqJEiqEzFe48A3nHbAQf8Gm
# 1QE8xC56P2xr28kjJBqkMM2DhDGuYRTYQd
# 1tuEJtu3jvbXQTvw1gAWo5CPdeXtytWYv
# 1VoPgpkkiaSA9twGFUorBqrDE3f1Ciihc
# 1yCVDs9A2feGxnJQHqsSYbc3iziM36RLa
# 1yN8oAQwJq7q1QMG38a9xeUppiq98VbcA
# 1ZgHWaPaQ83Z5iVRNTM2eJaAw1wZzfD7b
# 13nDhgwtKRXMdUzasvmus7tMDVJDivsoDv
# 14VH7NkznTqnTmebD2eAsg86jYAYbPa7aF
# 166qwaPvccH2NaG7NL7d3BeqQR7D2gvoEB
# 17iji6pG1RZVzJR8f1Jo1FqPpa9KRpkp7x
# 17Lkqi6Hvg9ybT1YaXyr8wkyNNCfoNzvwr
# 1DGYAwysZA6Zo3orbJaUSZfqfkGixyZnjy
# 1FbufNcXA9j8WUycWfkdRYsngNfQYpUi72
# 1FY7yen6UNgnD4han7hDtcdZ7pNaBdKaGn
# 1fyCPk4F8EMDZthwz2pacMLy6BH9Kkz9c
# 1GHoeaiFrYBzwfFYycbjQ422eFTG5fwAiV
# 1HjPyttmQpiVoQ2tCdzd5tqsnDACvaWE15
# 1HPbBjityVPvkcdBnZAjH7npwg4n1Hu75x
# 1JPz618WvvptVmv1ZPBsKV4rweFjM5sxuu
# 1JpZYM7vGFZSYuUSrqRgvt3ce55NEjvvHn
# 1KUJKraq6YrQmmgfDwxGt4mQACaxi6DC5U
# 1LjpEySgTG3PkdMRBmgB4up1DwZwP3APmo
# 1M8T2bbKDUQdni2gtew3MMhdXxBR8GjXUa
# 1MbL2Zw8ManmQjKNNjCqGGnffcdMF9MPYa
# 1MpUF6H9qJR8QvQPNR2fn1B4vy6toTanGo
# 1NH67Ut8H8X2aTszgbpRZNfKjm3ZUHfnwM
# 112GeaHKDJvgYn5dmxvnfhbtdvNSvEJnK7
# 112mZ2Y73SJxVry5gvAMBxZPVpSjhu7BDD
# 113dcTRnXMTx87faUmwUmU6MwVRGi23eGU
# 12axgS8AYUwZVypu2f8FtNVrH1JqGjK8Ko
# 12dZmZoMhaw9ZQbd9wr48xC4fzUvkYSGpT
# 12EjNEFzcX26V66HhLRDVJabCDad1vgEs8
# 12EZ7zzewGnygPy7bwEDHQrjzPtgVywhFG
# 12HzuqHQRJDtYYUAEmz51KbEwMmeorKJab
# 12J1brXxybhZ5nnVTfNJvTWoyQMR2mf583
# 12QoE2oFgAcFDKQE9ShGdzg9HKLbYVNgeP
# 12rLdzrHz8cj1VvNfkDit8KzBa2g8Sfofc
# 12XosJeFZG6vh28aXsBVnuDGr9FbMCpEuS
# 12zZPZC5MufxXrGkKJAmeVx4FKeLQybEFS
# 132kay5h1A8z7iWRp3oov9CUJVwc1S2LeB
# 134h7UNfAShZgRGna1CXfzjcacBjN8LyVZ
# 13E5D21UZG5uUF5cG9FHTEhxDQ6PbTMtaD
# 13g2U1nkkgyxPzhUDf6HcFhyyhpdqyyhDY
# 13gi7FKuJ58HT4RiKDFQL1oQpA1X4X877s
# 13gJTSzdrTihofXA7JCcDmBtM8rzpYcKSd
# 13KgfxMZ8APQqMEN7zA2wipxBYeR4NAVpm
# 13MdW1nS6LsoEu5CwDfqopdJQvuBfiXQcn
# 13NC6e2yni6EtHau9mu6X6GCjuyihYroCt
# 13qhjChdDDf5h4KSHCvRkooLpjhHmbMFt5
# 13QqxJj6FBXR9FMf2P3qnPgtg79DTq1FXq
# 13RmSMnYoL9qPQrrVE1EFQ86Ln3KzXC4qu
# 13RSRBMXqMkMkGgCACVF7wWAybB4hcsYjs
# 13Vm5H5iFJuw7F7xorQXHxpuDb9wdxGAzm
# 13vSwnq5Ntew6KB25cuCFe7LBzNYuh3Swg
# 13W3xamyBtQ86cuiNWuYZ6UgFMmyXnK3hg
# 13wbPQt7j4aBrYqBzbrBESTwae4iqsfFsG
# 13wFDAfN2WMkx4VF9dnPWLufMY851AoqHV
# 13wT7NmununNpbn1RtzfRqSE5yBnxWtTSc
# 13x9WYF4QP5LWCcGSQytft8yjXvSZDTYgb
# 13Y8GpBKefx5LZpSwVQHSAffjCgQM8hiSc
# 142pxhqzrUtKkmsEkNcjhNK6uuNdMA4m9m
# 14398h18LY9ydaAjTLnGKs1GuR4rWkQ2TQ
# 143RcBXUoK6F1yCdCCqYWZ2ETBHu3Ue2K6
# 146ajsZNV7manvdStEyGEMvYN8SQ8nSjH5
# 149MuXiLpWhJqausS7UfTyCScWsATkHrFi
# 149rXyDErhv3wh8otYG6qbR2gbSaNkaRqy
# 14BTbjs9rMk7WtcJjCuKHKaQgrVHeuAqUj
# 14Fu4z4EBmX8Lq7H3whG9bUJFLAdBDEevY
# 14gjen7dzEtjvcfFTAhApuGsydR44NZZjY
# 14GJqaMzg3uuJ8LJvqwKxc2MctQc1zYPjm
# 14iKT5YhshgMQmvXyxFqzmg412aNbZZ3Fe
# 14MYs2FbWY6Y62uYd3htuhFVNsbKmKwuex
# 14pnSaBqRubCJGCmtYZk5Lnkgw6D5Ybweg
# 14pPxjPrHemBSpUJfJb4uDJE1CCokLnoCn
# 14q9jjGefbCEszbNJJeCiEZJNfEre6K1ce
# 14qnuuE4XDs7F7xJ88UN2QExcvueohUV1n
# 14qyFvaEQrypLZJKJQx1v9YzwZHRGZmNNo
# 14RKVYmhGPzLGb9c1XyjUcLYKmng1E2FqD
# 14S1sNSos9t6UcsSmE83w6DmUtf8DEwUqn
# 14v1LMhGamozRjkYZHeYLMeYyRpzqHxnS3
# 14XRgAceCiCZUnjK7XVxQthTBsFCq6px48
# 152mKjqyJo5NFLuRFHbm9KjCLxY3q6skvh
# 1547S8Y4YGNTAozcmFMZJ73FBTiuehbbeX
# 1556C9ArRcBnFwzPcUy2jmjjzCj1bukdo2
# 156Gyu1EXXJJa5wjRjNeRR3dXEQww72j4d
# 156zmJJqFsok96F3acCG46ixKr2zbPqJP8
# 15eUfpGRrwURexYfaLgyBhUuvAdzcKNeiE
# 15fgtF1CeGen29gouko9H4EWcph5wk3aN9
# 15iohUdmD1H6j9isM2w8BeUBJFYbS8mcWo
# 15M6eJPSQs5pf3dWqhTW7xWkLG9mfwuXX2
# 15MRo5cVmUTeU8YwMxQetG8zN6NZWa8p4N
# 15q4MLxTXVKf4cKQn9VGniMZurMsoyHFUo
# 15rhJ8icETLgfcyKBN2qkC6NgTKMByBLbx
# 15RKtDYpELTrWchkoF56vy4nAidiVro1nE
# 15WHDQfa8Q5KBw1RxGfUwwfHZeunUN3v1P
# 15WtMg5nQiHuZciS76CoArzuST2UD2AzEi
# 15xCJ9NDPaW5MEa7eBunzhS5RqHYGyNpVr
# 15YSczL2YD3mMHoCsfPVLLDwVgZqXruAbW
# 15z7HKCV4UHPePWpXQTw3EP21ts3g84yFf
# 1624djB63V7ocFDFojMbj5n8DuCtvWrPjQ
# 169WDRhYY2mv29d9zF5GVoaHB4PaEKTiYz
# 16bcpZownr9hhocLWUdmtt4pEQVMrYtUPE
# 16cV6PKHUbtaHWWkn48akR68LACoJf8Bin
# 16D7P1zVWd1dDVPjkS5PNe5LhrRyeJjbUx
# 16DErQWDZW8enuzJ437wgnxMQ4rt2B6TDU
# 16FyVj7ZxkoFn2MBsXU7tCJYwST1xRDuv3
# 16GMsqWWyna4Xsom3rpmJVFw9dRaXKNQyd
# 16jdTkPWZKse7JdKN8zASUJVvjpAYDNZ6H
# 16knCLyretey4QSCaznePsMdBk7DT1n8BF
# 16tAY5gTm5oaLDzNbmW7KUt8dXjLb9JoHe
# 16VYtUk2N4EpgZwqWCTAMTfUtNdVxTJvqs
# 16YioJfi6fo7DC866jTeykM4AVYbC5BdTL
# 16yJ6aLfge78kL4zncxNWUpT6mg2DEvYuf
# 176b4kWsXNNkNpux92PLmuXoKzPxAuvpqW
# 178H1j6Pc3epxPLkizQFhHizTihPgGvHwA
# 17FETyTzBZb92a3BTt2zKDqeHmfFwS2Dq3
# 17K9P5H7tAuhQ26KsCBGSJneJyzz75ainB
# 17r66d9Sis99eZWtsZpEuK1rtpZCgr2sDU
# 17RgoJfYk6E2gr52NNXNHK1aQF1TVHtQ7E
# 17VBsCUEdf9uWVpnjM4wMdSCaX3fUuJ6dZ
# 17XMHDgwspVorHpwJGVza33ZXMhCbif6Dn
# 17ZCfhxNzBDXZFmf1HectKtke2yYMDLiX5
# 17ZX6m2rmfA4gp3fzSPmtarqzEpjLvys8h
# 181jvSLNi8VY4orZMPm9CBd1gYAnqCXMDj
# 181QyisEexB4e2wSCy4VGvQuFQDHLErKKW
# 18brtDN8oknV2U3TEqoPdV8Mn77paqsFuR
# 18D1PsF47EMXKck5WJ4cjsEPFGazYqLf3t
# 18DAeWM3oLzeNrFgryiXGJQEjPJw82Pybj
# 18Eqe8wvGVMyP1T26jeoo4Uw11DEdUZGcP
# 18fAjih4GXK9yx4tZY4BY6DvAH91ZyGAuT
# 18J4VRTP3JS7TXuteSJVMr5JDjQFHgfbut
# 18JNePHrCSd4eLF1RYYJ9qua3hsxCTmMk3
# 18jW2eqpERVsFVQDwG47PoHtEnx9qLkskM
# 18KM2RovLc3kD7GKwSU8sfdtE2ykJPUQ4N
# 18knDek5QqKBoPuWFBkg2kq2tLXLhT1BS2
# 18kPbjVLvrWf2E7EQBkEQ6CJGiiCCTKTtX
# 18N9GT6xK8a4k9iRRLFbK4kW1ioNvvsPjD
# 18NuqEoAwkpYkAVNxUyay9jZSvJkFv2DMR
# 18onR6bkXa69VmkYvwfSebHxUaHHzNUrfJ
# 18QfjVeobMNj55Eso1G4Fo5wugCf9mx2bJ
# 18QoPhBe7EKx18NjnQPbxXAbqHtVGrbFui
# 18TRgm2TGF2reWeiukum8Nqd81bkPTMSRQ
# 18wotFvsigeW9zu9XSBixD7A2dZxZNqjuY
# 18ybWEJmqHSUF6GDdyNB6rGgNeJUjDUA1y
# 18Zj7prF5YjHdcpJVmXxpPDmwuHBBm8u9g
# 1933de4ndMZ6LjuJQBRJxBHg8LW8UWomBr
# 194NmQcy45Dmnb1PXNmobLAxbstYRCDKRN
# 195ehYEyNkgA21fPJ7kTM3D3DN9tME4c2s
# 197zVPyf8PTuBGQ5v8WtrbdpJx5v4qwXiU
# 198vhd8J9Y67YPZrbXckbMnhQwNncoxSA4
# 19A7k6Rm3XP7fxkrr2NGmtHih3XxpZGtKU
# 19ai2Cr4JLK8Gr7ggkLU6NPBGg1GLH8aTD
# 19C7jsEnoiEtsyotWG5nnMuHC54nrt6zUn
# 19fTJGX25a2cf7p792kbVUVKp6ASR7eEN4
# 19GXKZVKifjDpQnU8z6iU6PQyZjuBeaYFc
# 19h6rowsThh8ZuYbjymtZWJU5pG3ruN2KG
# 19JFyDJcUnfRSmFpTANvoqoMvUk5qt7Jo1
# 19mJBZ7Bkm2rN41AsXwmXKB7pNG2ncgVfp
# 19mnqzdsco7xq3Bhv6nfTFu7VNGbpzyHnV
# 19NB1NJPcHtNCJbbCCeEaX3aCmxRxTtcYG
# 19nMHdpDdGBrTJnN9JnNLj3QchLmjeCPaa
# 19PquYsFY1voRifg5tDJU9bv4BrpJEGWwL
# 19RYp7ssGwgNgMDMxh6dwvX9o4NuudP5WF
# 19SkQULaSiaqyiNweATM41StAYaPf4RXwp
# 19TPpU56ygSVoKLDfM5Q2pCzFSHuxiMvia
# 19UXJ2djYRxAcgZovGVTdskqV8pyWBjTJB
# 19Y7WCe1Bjv5XsDR8Z7zJyQ3uSzRGgYZUR
# 1A94ATsBHXoDsWDUnxA5wyQofRMmZmN2cY
# 1AgU7U5SXuPFTF8jAd8G1oDhJeseBTBHn
# 1Aj6kZhib1k5sVV3t99mvodU2JG4KGcp8C
# 1AjhMD8NJgndGp6CyqK8h5m7TJguwCmG2G
# 1AJpHSvb8DCz4nMyzZyguFzuEqt8HXRzvE
# 1Ajq1WduHntBTJsS8v3yUfKQJaXwUKcrDu
# 1AJwuiKzApBNGB3XNdikeAnKdx2M1fzvmU
# 1ApNHmNRKCUvTyLzAimUWYrtYTksEy1k6G
# 1AQho5yc1BUzQ7nvNUcbXSJy1KoosyE6Z7
# 1AqugFLG2gtRLfAT5S2qt2cuuPo51E1g5j
# 1AtJj5oj12CpjUkkVnZ6vCVTXiZ8aS8ztT
# 1Au9sfdaBC3huN4j7dQBtHeefmmBNbjmDN
# 1AXNCTFix9LpsYb49LU4ZLGD9czZHTcSmV
# 1AzewSvVhaGkJxpTKLXDFi7EgrJHnciHyi
# 1B1sMPwoXcunNktE4C5QKeVKeVaAGVyFn8
# 1B3CV76N9QLjPwBJEgnXMRN3pcFN2ruHrZ
# 1Ba9qGpqMDt3jFtPqsdFkdzE4nLkZ9HNsd
# 1BaPbiknxzLn4xmwkSWwxZAapPYkGC69nB
# 1BBJk28SWaKRvrzpoSSmEPqeRbQW1hCb6V
# 1BdJTCnstFUhthNXPBZoqKHcRHDHwVwMRQ
# 1BEebkPfBofGv445h84kmwgaarieMYJMHu
# 1BEKJ7J43okzQDyiBaLgjmg5sZuP4TH8xY
# 1BffL9aa55425t7rL5iuMkB5DBjyDxY6mH
# 1BFhkM77DXrntLa1CAcKbUZcsDaQNKAmSq
# 1BHiPCxiumAbWYtouGcNgwiXisMAsZxsfH
# 1BhoaAMAStk9EcVEVY6mXQRW4W94Si359h
# 1BLBdt3pgDEhxsbr6CTa3kddLmJjXj6qb7
# 1BM3sFXACadTGz79kvh8H2JaTzUz4eMYnp
# 1BosjcsDB4veq1T9mhtNvJbqzqYq4EV2f6
# 1BRU44AS1z7LSodNqmRDvPG2zp3razkiRT
# 1BWfFWB5HeRCvxXVLsKfQBQ1sAJJ4VTApk
# 1BxhcJ7xs9g4EiDfJaJfUVu88YhVTz9QFW
# 1C2Jm4hwHAgkSkwjkaXn7tqhBKkP8kYcqj
# 1c6rKWtk6Tr9VZqgarcnsWSCNMitubRfW
# 1CAxr2K1QKNnPNAYemBPEzbzHTCu5f87gG
# 1CBMypjkc5FsvKxYjdRT8UtqKSSq6EPtrn
# 1CCVr638WRWMCbehMjKcizzdkYBPwVoViV
# 1CEWRNMGzkZEQyYeHP64esAk4nXjZj7P2
# 1CKdzrUhHEQLqsV5S1NqBNEFB5uEvAevgo
# 1CPR11SFfB7UeBqAoJCYkzHVfxW21LGqP9
# 1CqTFtJRLb6HFewxL3UkCeh9abxRA9jQRe
# 1CUP7HfThX3mTe9rKV711weu1DT9wf2yuH
# 1CV5p5Y6GYA42eTeYRBgxpijVuHah4nfTx
# 1CxJQmwDCYGcC5xk5szT9bbzt5cvuvR5EX
# 1CXMrb6GHnVBo2dwWM23hCNRviKZr5YonA
# 1CYS3dsMMW815nxScW3LMhor8brynzdMby
# 1CsEhkLErUjfRV1xS5h8Tb4PPppv4MwhH9
# 1D21tGQEb57ofiSgXyaaou3aEq9dzLcxur
# 1D35XQySTedzty8fDV9iKnPVFY4ZzrSvdF
# 1D3mb92waRe411dXx1iX2NFsZpYFm5ATFt
# 1D8zHdJt5He5c2KaRydbQEC53AMM3R32Ea
# 1DFPwoBix9CLaCc7adAEcVhYBbFX1h55c4
# 1DH8odzRFe5uKCMss69aFWLsdFL2pPosnm
# 1DHnZdPPdCDcLmtpcCmuHt9CD8KGqzeGmC
# 1DoogLUS2B8Li2rtgERwpBcdQcefVABNqy
# 1DooGLUSx1QjYpSB8GEiMtbrGDtkmRV4kx
# 1DRa75vobrWrKPjwW8XTsZTxufMko6wag3
# 1DRBdCUbVHTSxgtBppBSBwgGbDeAXbWp3G
# 1DXRejDxvqxeVkButDdxYu4PUE1jPCx4bW
# 1E6bC4KY7tkqbSk426gye2Am7fTP8gpHcC
# 1E88uuBQMXmaLa3WvjZUjgGuwgxsLv5zqS
# 1E9f4F936mauvCNNsR3LJCCBMJLSs8NmS4
# 1EBa9bY3xH3WzwaWdy5Pv9ETwc27jKeFrE
# 1EBjPADFmZFRWVcbAujE6zpAb8A1jNrqZY
# 1Ecq8zjSGed5TJC73kGVcnHo4a76m2FejG
# 1Ecvzvw46N55NqUN7UwLk1G3ZDETbWNPC6
# 1EdvbMN1pqQPjeTnvpVUo4wRTUD1LoSax9
# 1Eeco9o8sNrArLnhEVSCUULaoWsmd7A4Wy
# 1Ef6HWin7DE8pSAwjgzevRNrwuS7mVm9dS
# 1EFWq9paqMygfhvF6mPbhUTCyDf3xzSDSi
# 1EGExxMHyaGSqsina7xkwChf5Nn6jPK14E
# 1EHLfjFKsxPWSYjsr1vugit9jAUo2AduqY
# 1EMCWUQZ7ToxL5kyAASeqfvaUzkgh8cFFQ
# 1ENXeDsSrbeALrBbVm9VdLHaxu9MzDEtWm
# 1EpcRd6YM7jri6CvZnRcn4JA2mNm7J6FNe
# 1EpHMMyymjZtnYvyXEC9577ZmZykp7uc8r
# 1EpyqbpjCyzu7FTXxhcVCsZVqyhFWNa1FZ
# 1ESdqRE7NaMi76jRJwMcgXMqQv5QWc6Wvq
# 1ESfgXGdsLsiN6zad8nYfq79xaYmT8Djt1
# 1EX6yHACUtJWbWCuhGRYoNtKpp8HADKMh1
# 1F29kGNNeShfCGwPbYukixbCeJxRTLx8JT
# 1F3GQgyxANP6HbkUia2fL9jJmqqeib1orG
# 1F3LnMkGn5G22XGKfsGu1LDSM8wtHvh6Dh
# 1F3mS8JcApqwNdgc3DJFhHKmcgmH1a5eEL
# 1F4ZQrFLD4fAA7kD2m7gK9wvMHvau4ZYJ5
# 1F8WM56cXykLf91Ri2bHhWtRmQDL6Qhti5
# 1FaVQUiNfuw2dn7kEnZ7ujjGVvKqtau9E4
# 1FfxHMnywzV36ce55RRj9y19ttwf15NE4G
# 1Fh9Kgg8j1JCjvd3dj9Crgv1QWogW5W9Wz
# 1FJafdpoeNvFdTTHvzuLWuTuDyqDQ6Zj1j
# 1FMd5nEWULh26NbLVNssYRu9kXRPTk1QMP
# 1Fme949Xf7VrxaK5LFATd8taPUu2bjfoqr
# 1FMHduYindvzeaH3jfVXssLT7FsXJViThN
# 1FNo1BMiniGgzjWQNKvTtLoyNmiz61Q7YY
# 1FsMpCkMD5BzPQiPSpE7ccQeaxdi841jBW
# 1FTbu1nJ8tnKfqTgYuhefpHokjg1GkzDK4
# 1FV8AjMsxLHhCwwEG8Yyyb6k73UGAQzQyb
# 1FvcHtYSvWyATeJdkRKs9M4faevoJT5UAT
# 1FvHpWYe9DMmW5UtXGxk9HavFTNF6Gv8WL
# 1FwVKfbp6Bh8T5ouUN7y31MdJiasK6m5XU
# 1Fy5dAzxkQT5yYkkPAwrsVb6TKc1mnyCZF
# 1FyNSBiWAmxDZRQbSatFFMt5x6JdoG8Nwk
# 1FZK7Kv8XVfZ8pjXpCTqtmhBbV2e2tvYxa
# 1G5KYjWctW5FdzEmALaz5eoQU1es3AY1hQ
# 1GAhnZ36a3DJpYXZW3xZHX8qgpfYoRSS3g
# 1GaWppiE6PPRtVzqC6hd31AKGQJwCK3V6y
# 1Gdv9hmtbL2g99C7Ecg3RjLBHgTwi1FeH8
# 1GJ9XwddFcCFJU1E7NYRV3uE2k5q4wrx89
# 1GMkf57uXDGZ2wQUSPmcxvwqeVRupPBfK8
# 1GmKGRNyVf4kxaWwnEYS6hfLCvfjfiEQyL
# 1Go1ghT9WXn7mwgNfMoEDpexKgmNiqfsGo
# 1GRmqir9Wz3Skojbw2gJmYZ5sJ1QJhAPRm
# 1GuAB4Rnsg4cqjYXPmkkK45MP1X8NnBqY7
# 1Gwfv9aDbFsSmP3PJDiqKKwymoT4HR5YJN
# 1GXBP62FLSQmFSEwELCE8gAGs16kJY8Y9L
# 1GXkheVkUREFAfzTdproxbcEqC9WFnePsP
# 1GxY942Fs9zg9gACqpWVWuZQuEzJn5VjbY
# 1GYuffMMvizyDqdRTuhGGN8qBfugYafFeJ
# 1H1pk2Xjtx6T67YaJBhRy2EdtvTR5d3rxn
# 1H27iu8koBYST4uXA8kwVxGKekPtCRR1uZ
# 1H9cZ4SnDpBggaH6ZVw8GAEndVZeL6x4cE
# 1HaceuG9g5H5wKBoqTGUubR8KTmaR19sfY
# 1HCdQW9G5zQQera6XTQC1QrPANvsqwscKg
# 1HGQmmSMF1w6WEF1bYJ8JTy6gy17x1MCom
# 1HhxneHpiUtXZZE1rbdeKMtWT1HLXGoaTi
# 1HmQXhWRy2ZGHE1r4SmjoMxPNvhEnW3xTF
# 1HpjcvTiqny8axERQjnxZKAsJLH3NCh6gQ
# 1HyjZ1VKnXCfWhJqDMKsGmMmiYDrE87Ard
# 1iGfgtdAMYSygZ7RNJmoe3p1uvdoxgXRq
# 1iqVPcmBKU8gNZDGGsathTZ5gCms1dFGr
# 1J1QWSmDPPA8EcrMLjEpuCXhkkXzHwkc6Q
# 1J6JntcZs8QeNGK1rVgnY4BvCVcvSdN6z1
# 1JAMji1MdQAJd7vAzX8XVFo3aME79aZGRj
# 1JB8zbKXTs2tSw5gDonZw1wBGF7ZPmde7j
# 1JEdmejfUyMrH9yGycM2HhXLPDcu8VMgQ9
# 1JFr8N1kZt1y1q8rxJWJKd2bapSC2Nw9Hg
# 1JH5hME5orz57RvvDoo4LaQ2V9VrHJX1mm
# 1JH9TLQZ9Lz3DSHrdoZggYQiBPix82PvaG
# 1JimkrjzWGKtdtx7a4ZFXiSCcyGq1GemkZ
# 1jjby5ZtLG7CtR5p2isDwpXtrG38XwVmk
# 1JM6NAroSgqP9PtucRGMo2xjZB6kXHQS8U
# 1JNEHSSKQ3sJKdLCd22xFLWyjQyrMKbGvw
# 1JrCmMDhtyRRQNWm9hecJuX5bafZXreSut
# 1JUbUoZd5EFRGdBse9wvYAb8GBT9Ph7xMf
# 1JvcGtWRoqRNJNmUr4hGN4UYSvJP3z2NLV
# 1JwWDKoPnaobyXxFySTqrNSYgRJgh9odLj
# 1JXDq76gJirgk5v2djmdo5DjtncrGXw4Tm
# 1JXEKB3FM46LbL5sag9hkAVmWFk3AYP9pU
# 1JZ9W3Gs11kFE3zY85hVocZ6kPCqoJrm7p
# 1JZjm8F8jHirQVj72WPfeJvtZ2CMuuVCq4
# 1K1uaAiRYvjMmMVgLdGiuwCgWdy2BMJe5U
# 1K9sh87toLUY2YPntSAZjMoWf29LBLont9
# 1KDjsRoGyXra1fYPN1hciJ39KeC93gRwkX
# 1KDzQz9YYsgKwH1Q3eiYH2UfH3U68KddeA
# 1KF9Pv6MAw8R52AA2yNFoKgwy1zgNYoo1M
# 1KiRS8GsN13tJyQJXgNMUoTP6sRuFLDpYj
# 1Kj8vYiMsKnkVHd2xnwTyo1uHoGtX7jwJf
# 1KjjqJcJVFKDVEpMo7ZhjSgatjmq4VJ6Gh
# 1KkbM27SaxJqFSY6oBnTT9cwA1Sjf6wanb
# 1KnCfaragZwfVCmEFuB95B5qWeqHnH6htN
# 1KNKREaJ4Kw8KXnHypL7tcWC1VwKUXGAQz
# 1KoJgL9brDwLwAg9oC4kmffdpR1D8xnBLo
# 1KPZoAryFAwTtLqFzGG7xnoUpEy6CZRdHA
# 1KQeJGijtGWojDnacW7RCS85HGGBnzjkve
# 1KRGJ9sR8zWvTEmcDoNrQFSv6XFyniYRET
# 1Kt8Hx5LRTTaiMTeT8tTdTeE1atEyJ9mJN
# 1KuNc4rcA8WEgiCUM73pYRqFzywpervG59
# 1KUUxeGpp6FTtsJ4FhSf4E77wbJUdEomyA
# 1KuVFnVTzBjppsKqfhGLs9wQ9XMdZbc99Y
# 1KwJqN6TYDQQdDVAd7JysvoxKPiZEhf5rz
# 1Kxre7WMxjGrMx1rQQnCL6WWYAZUqrEnw4
# 1KYJ7gCj2VgkjaC2yLZcRp7B5D3aadHoBj
# 1KyMCdXqP6orUZgYJ3VWzrM7KjREmkPGPq
# 1KzVUGvjQDoJdRqbFozWEiPB4C9iqPy96k
# 1L4DvuYEZmEyKA452qfBuh4kVFY8uY2pP
# 1L548imRt89hEKZJPF2RjhUuGAR4FBbg9D
# 1L7qSgPZkB5uUXdzu6WPaEw9q8LmJzDuo1
# 1L8MWxd5RMJCwdKDMrCJkbGV6ZeSqUk5gD
# 1LBJ7BUUq8DzSgch7NARuWfjWyo9JjCHpQ
# 1LdjWinXngG6DXryAX7LEcVmoBoNbMRd23
# 1LfwoENrSDxd8N1djHZrjHm1XQxtYo1zUb
# 1LjHVdRk2iZGqe8uRFeAtKzvipPSVAT9NF
# 1LJKEGbzLFsYFGSmJHFn2W6G27Vb6KXpYn
# 1LJwoqCeKNinoubPfis4ws7pH6vvchEGaw
# 1LLxNjiKPBwyQ5AFW9tTrsJqDBL3mDGpxX
# 1LnA411EXz9Vtd9RQxjK28KBt9VqxsQurC
# 1Lo8SC8oCxyiYMRLorRgY9V7sffFZFFHDw
# 1Lp6viTX4yQCaYUuozh6yFi1MRvXsydwHw
# 1LX4EavV9GxXt5uEjfx3bjCa4nCiCzrMkY
# 1M1VEGN7CTf2URwxXF9FwwcPyGUc3UDjmE
# 1M2N8WFDfYNMjDpNTVLEwBvbyhpJvXG8MT
# 1M4bycxhyA7Ct9WhbxQNGxzkH8iBLXT2AR
# 1M4L6HWUUnEQRhxEoTDUiozD2ydSRhrccy
# 1M5Wop6GvzBE8Qko5v8onjbGYckLkqk64W
# 1MAMMjcb3rkmMt9hgmRw1B6pomeG1WsUEP
# 1MgQgBNHfnuCceUCicGxrG2RmhHeob5Ao8
# 1Mi3enEMy3GSAYSoifs9L8jZ2c4A2EZ7co
# 1MmpafKWKVg736AT8T3qiTiJ7JmdvLKfRR
# 1Mo7TXEb39vpz3mvp9JDJntUx6ydk2Dbg1
# 1MP1s1wHFytaG1uN2Gu3RqbUeDKJbdniR3
# 1MPaim6rhuP3Vg6UyEfWAK6VpVgyFmFExn
# 1MPauccxfVKfpVfznVg9PuyxMoC7QsdD9r
# 1MPPWQ7nLpRvNBS1HJgcNA4gQmKcNtKbck
# 1MR2PVW5LCktJXDczVPTX9Q17qFJr9Cjte
# 1MscJ86qhg7FQ1rZqE61ycPdkS8Fq1gYef
# 1MSUcR8Mhf1gxv2eg9NUtvYnTjfSBqP3QU
# 1MsV7eZu5VifHMzdYDqLqGYr59H8H1uRdH
# 1MVQ2u4EnDM6HHLp29Ro51eYh4igkLdKzJ
# 1MW1FGp9KRkFxSG7eT81rPUHfXivfV9f59
# 1MyzTVfs1G9CU8DCkuZXn924653Bbvm8QF
# 1N7TJkhTgQbVVQvKfvF3ozwLuEyNXmU9gB
# 1Naa1woay1vxqQWXJhodQA6wbgzdF4cYYm
# 1NBXPkSx7ykNLm7or8nXcPW4AYV7tU2Zkg
# 1NcF2Y9aHcxKp9Xpk837ZrpGKnMT24QL13
# 1NcGdCWuPcbaGMutdQ6ozwT39YRmPXW1Fr
# 1NEAif4X7dqPo2WjGDma7RfA3C4GekNf3w
# 1NgMWpovFnDuqxmfwqrFTZvvzKhvqaSBwq
# 1NJ9UWbbCGdpTe9UCtDLpi6q8Nd7WzM7wh
# 1NLqBTFB9KaT77CFejDociSM2D5cyRq4uy
# 1NPGLYMF6VNTXzbAa43XxCaFDqkQENiYaY
# 1NtYkkh69PbpHmCX5EiED4i6Wga6jfjd1Q
# 1NubWHznngfHzt9k8cCL8S5k8GYvYWms5P
# 1NwCWhKGVXTefdVeZcgN5Pw2f2yfewFKjk
# 1P1V8QbztP3ooyCMBeTFCuUSnFoXo9QBBN
# 1P3GEoCe1ye83WJKj8xGB989U6MrG27ej7
# 1p3jDbHht23u6HoecVH36ojrGeue8bTtG
# 1P4emHRiTpefiXyFF5EZgzR8xxNKdSRVd4
# 1P5f74ShnBaaTWBrgEVCyreZMjqn4iuC3
# 1PA7swBwPxEUB7oSN8dvL3Kw69gZ3esGUD
# 1PAkyHTewCNqmj4EEdCWofnLHHspCJJQgp
# 1PBtjwthgMDbNsnNd2xR3AK5SEeC9MVXeZ
# 1Pbu83LWKgc4coLo9DT8BWfZUvyo3MrZwP
# 1PEsf1yamqxXtdNMXNqBrcd1AVBX5xLc8L
# 1PGRaSgZXgMfhLx5PwYxSvAuwyszB5csE2
# 1PigHWDBzBvbXYQd2QM25Dt1GtJceA4LVG
# 1PKBg7G3CxH3GTj8S6dk9mzVhcGrnuAaQg
# 1PMUPRNN4f3bqfNpUT1dfqEsKwJneEZwot
# 1PNj9yJF1fqKc9dR8HLMd7PD7nAGnhcBvS
# 1PoE3YqnJbcu5KxGtF5W8ovdTFSgyfNDQx
# 1Pqn9rAJup6cWzd6JrhJVPCmBTqVLN1y3W
# 1ProUdsaZNf82CZe2F1EA731wa9iuMeFQK
# 1PrVzMVozDGj1qfeDN3TtA7ps3i3qE8Awk
# 1pS4Mwv3oxo3hoaNKsdvHXtTES4xfjFpV
# 1PuEha4WTxy5PmefpAgPiqUKEwxFaBBPfF
# 1PvgouioEVDghDyN6gf4ZF3EpNtJGkqgaS
# 1PXmyiQmMy7ytbEuQNDTp55UXucXp5wdZx
# 1Pz3vX3WXEYik7ByfjLwJarSVSh7uAnpv7
# 1Q1ghhpxgV5uYrWDcLc4Vdyb1a5EDtvutu
# 1Q1Xr3NPSm3JK1n8mVeZ5N6VEJmXn68Xcq
# 1Q2Qg4ZbtHBXxVPFfAthBGYTk9pTs4Dv9u
# 1Q2VfZNttj47ue9TCC7DWNVzSjpFYEYdVd
# 1QAM4692ptS6fp2FJVP2q7tYe2iXBFUuJ1
# 1QBdAKxwuGfCrAk2T5mmKaxYuG15WL8JnP
# 1QBN2FYx6NoDsqqp1ey6TRa4765t5vqaqC
# 1QEbqjibPJv8R74faQvFWWTBVji4ymP11Y
# 1QF5WScYr3S4QXHhYqisfYT2rH1W787Ejk
# 1QJ6Z6EdD1e1T8boKoiLB2y4PRREaifJZZ
# 1QKF1z53NY5ZdTzRXZay9rYGVGdEQYKgBZ
# 1RBweiBCy5XFBLvXkWvctH3PkmcMt8Pdy
# 1UqEVnDVBVzfcBmn71ooTt27XwwnmajWZ
# 1xNRy6dbdsK1UX4U8NXxLVu2wx8rmkjmx
# 1y3nMt4oGCrfoyySbdTS8j2TRvvGCScpJ
# 124cv6EtEUqVELy4Wt2VQ4njU9rB6WSXzz
# 125bAqJfX2anGzarTmd2oxeSsa1dareZca
# 125LAK5doFPDyFJiSAtfCuZjYXxpvfT9tF
# 12BPncNFk97Xg7Wsihz4r4BqCaZkS3Mgog
# 12gkGu5EN5eTMauJp6NX5oN8dZnrhBec4P
# 12hg2aTAU4ZkBs2REodaLgEvZzFrcEgAu8
# 12qytpD9EUh6njdd5VgaA3bkANccFJhwWq
# 12rJM9Hw3Y8kkAPxykqadnoqpQmXmKjJRV
# 12vRvoZEJjoXJahKJ2KGaSsRRkFvFiUz5q
# 1331faLWG3NfBRhccbZHWe2b3yaU8U3w3U
# 135xPfAjEGqKoUvaMYSocaKR69Nw8qRZC4
# 138PyjhXyHEu4aNhw1TM18UVzvHspYWEh5
# 13AoCuU6JcyhpjGUg1qwiN5PVXDC91DDRT
# 13EXGSoFxA9ZjyYy7EVdS6ziTfoevqTBNV
# 13N1w6Tvm2w7e6jCzRwgPJ3nM1gxuHuqoy
# 13Tu33kRsz8oCzDYi5fBzhu8gNFS4ZgkAJ
# 14bTLjGE2NjbciF6Q8Bb6CfyrJ7sywPrh4
# 14EeSsoZTQvuVJDYSvPNHof2FCm8u9ASfP
# 14p4ed2GNQ2d9HvDTqdUEPC5oDFs5Qg95o
# 14ThDw8qCkf6VRAx3VJ8zdx3dSyEFGR7Yc
# 156SLhkMvQ1AoK916KgRRQyG1zuSZxswyG
# 15a1v8VdFfbA6FPPNg5ksxnXEn3m8b8k8o
# 15BY9zXhRQxouLrJ1zQRuZTW1RmTTjfwfk
# 15DiHAgzU53AsWhahtUnD1EhmpvJCskdzf
# 15Fm8CXcBAkV3jdP7o4ywZDAJkZQhMgvLw
# 15mwT3joqfqxp86Mg4R2x1HaaybsP9dQRc
# 15PDv6D4z6vSYH7oQsSi3Vwt4BN1CkzpEg
# 15rg9AzTAz7Djrrrfqr9Pw44yEiQQvEVP5
# 15TtYctwQDU8fFXUW3dkuNDkPEUX41Ej7M
# 15yB48E57webuSz655AivYPPMTKhgqzY8k
# 1622LcVxqKdRJuBc4qJ83KhrzFR8c4gJDN
# 162uFchHNs2c8u2nmhbuMK3teZSd7GZkZ5
# 16f7ENaEWPCbH6CE5SYJmDczF8hr27jMBu
# 16pcL2pEpesJExEQTd4dxc8TW5Nk4yBydN
# 16RviqWyQanpJhy28yvdPFYnNoFGf57Cfe
# 16Zmpg8Vhf3UffNVF3aWMNMgB4EHVbQXX5
# 173TwKvuvZkQ2cvr13n21D53ysRUJrncJH
# 17BhjLpzLb1PdXpPq6ndrxFN9nQjmeqbHn
# 17es5MdR8aWfSngnYo9DWK415RrJuNgDq2
# 17nRAqit1XmyXToxdjjLeT2x8eaLYeC2as
# 17rRhwVLyv4dJ1i5Prz277Zr7H7rqpHNti
# 17uxQkNBrNM4trTVwFNwJQL4ronciufvbR
# 17xDs4VJPfxQhHbF8dP424K4okQC32h8Hw
# 18en8JJWVrBpWwgVoJXJoV1bf3Kbkdn5ZW
# 18fzjE5hxHhvUpG4Qe6i3bgw1XQxXgkdar
# 18qHSyG7kZ5Nqt27cfWVFsRYVTvkYSCAya
# 18Vqdhoy6FC1Ddf3tH9Y7dAvxCbxxpC1dg
# 18wYifDhFvAnut8kXutby8PsmhvS2rc9bw
# 19DJdyXFeJfnEAngwWzVtW228zPSTZ7mzz
# 19nKDsGTfNvciZFZH9mniepTjK1R2USbcj
# 19ykT3jrJieYR6wvS44X2Khxnb2xKDPfD4
# 1A6DVzJqsqUr8SfA4SLGZ3XyK8NToLTAY
# 1Aenv361fMmSwzcAPP7YPMgHLrELt6kU31
# 1AetmcFMUfzjmDsDPZBaQ78KKtraWwCND8
# 1AHeAiwzwXkXhefzVzfkvFGfpc99YWnMQ2
# 1ARGumYCz8cvxKE52jiAoUaRiURd9jVzwt
# 1ArUrihHVwFtBTmvVmKWhAaSLLTZr5VJTf
# 1B9WrD2RW8EeMdMicUDQ1xfmDD2h72zWDJ
# 1BpTqYbo5egz3EPFGftjkQ3QuyptyZpFmE
# 1BR3D93HLWhMRUmQcxG4Gr67tmwV2nHv29
# 1BRUCYScQ5nUyUV7qspXMc7VUuKFE4Cj7L
# 1BVYFyFLHjdwuN24WuwkjFCHq7ynAFitdc
# 1Bxofo5RNf8uJxtAWdHdKTDU8JRRFR59w3
# 1BxZfhiDHhqqtDynYu3r31THRiy8VZkejT
# 1Bz91grn3MjycqKynRFrvJ4JGhh3339fXr
# 1C3jCb1sEjjQ7mTu4kjd8ASaGeDCeP2UQP
# 1C5puxTMhQX9cvkECHTx2FUNxcdk7dPjuZ
# 1cdBK6fEWb11tD8TDijcw5QpRarcSKP2V
# 1CiHeQW8paM6PQbdrZK3Wc4BTc6RN2dhS5
# 1CrQJhTJq66a6MUGTtj9Q1hXaqzxJNBHbC
# 1D6ZWDsih7Qtm7LvyrwBUFiyyp7Wgc2i7c
# 1DaCNq3VU2cmMVgTmzjru7Ti1SjrHVgg54
# 1DevNss2iDaJ2usZ9pVyvEXCoiJq6L6wAc
# 1DhErD8vJEttKnDd4M9HwnBjazjH3HMtWk
# 1DhL5DsuKG4vnoqGVegEN9wPbDJyPqSPJZ
# 1Dib7ggaX5NvwKdf429EEyVrwiCXnkF8Ki
# 1DLngPDayct84LZr2XqxJvsaLfP7RmMLB6
# 1DQtqRc7T4PDPSBpg8xv6mxL9Sp5TaxYPn
# 1DrfESJeckJvACWNmq5gwMSyWbaLiJCoMj
# 1DwE9bajcENwiBi1u8Tb94xrBKWxfQmwaY
# 1EJL8Qmrc3H6hYmrJTDVjZBTnTa2EnuE7M
# 1ELDikPJb3sKoVkW7RT2w1Gvg4xbbFjpdJ
# 1EnKN4jAjYotGoZ4aicybKxyJ1hgpAZa6t
# 1EZyeFjDquXFhKKLXPK47ovLqgsm4wRrWC
# 1F9DBKtqpatPN1ngy1prqLHJ4QERCWu4Ly
# 1FFSSUo3P7CjjNQkjAqY48gbV5n7zQjDL7
# 1FPka8tPGtZPgCuQYTWLGnHcyh1NQzRrCK
# 1FsHhLriiWf5aVVLR3AzNvDwWSn6hpfCcM
# 1FsYZYPLe6stpRa2jUtjg6HJxJpbgDyfAU
# 1G3c36G4hCJksBJ1bPBNjVTNm8moUCzrJb
# 1GABvpsgxZLxcTDCCmyoHPx6CdYQwt3wvn
# 1GaqEuHyoUttn5CR2PcsLpV9YZT9sweGKV
# 1GbDrpVNGxC8CxfZrYMPVPZ2KNwvcXEHT7
# 1GDqQgjj1Yh431segqAsPH2W3bFZ2VRtEj
# 1GiiHBLDncvgk92ToanDydQFj95MThzfLP
# 1GnU3Ci4JBeSoYP1xEQoswUkePf1bDRNsE
# 1GqF3iqrZwmbh5WAs5iDcvVyvM7MJ3wY1T
# 1GUpVYwyXy6t5kb8REzwwnQCCtQf4gxH3M
# 1GZ2XfNdzNQaczS87LgP6XifabSUPUPPh2
# 1HapXGbeoyTQqugWoq6Cve9Qqn7mc7iKpK
# 1HaybmwrQFUAegBDtBbRBtvP7TvJq6u5Pm
# 1Hca6iWYwJr8YoqzMyYtdk3dfbLsKvgAa9
# 1HGjo8MgcvxNBUU9XspFA9H4tR95kjhVdb
# 1JB8Xkw3ochFBN7EjdudaRzPVzGN9M6yQw
# 1JcAPiDARA1Gupg6ZqH3JJ5KNPBMzcErp9
# 1JEyPuAxFvbmVkHTME7Ddvw3yLV4ZQhEVN
# 1JL48csvzCiDYHv5Na6S98RL1SdUUwhNgV
# 1JUuUoC1PL1sBUC6SrMdfhGapMnE1i9Qkr
# 1JzbBV9DnfmZcWNPFi5p1qQs7a4mYJdEes
# 1K1KFfhkYTUVPi32uQUfDXqAed5YtLGDMn
# 1KktMxkew85D1skXxoqP6SaQaS3KYRPCus
# 1KLBRGzKaLh6yBqgmPPKZLw2bfNSdrpuVN
# 1KyKH2TJpgx7as9CkEhQ3gFjYJTfWVUyDU
# 1L1xyzFpNKg8Azj1chnPCBrfKpmLzyyXrv
# 1LLmgHQV7Aw3wWBNf1g5vLm3oWDcFW2wbt
# 1Loyhb3Zr9FuMP21Camj1CefkzpGUec5nt
# 1MCZgB5vMFvDXyVEGAcjVCw2nGSKu76bTe
# 1MEqDEYFzxw6QywQuWhGBLxAgwBJXF7RfR
# 1MFiyJrZEJk2URwMHVvny2z8psAe4KhfJ8
# 1MgZW6uyuWjTRajXtcWhSA4veZHrrKQjia
# 1Mh88hHywUF41P4tEa2zExgBWaMpE3kyGN
# 1MhTp74VqSdTSaHfKZKPMRwZLLtJY6m6vE
# 1MkJF3zqgPsw9qtzGiqKC46zPB4GZT25oF
# 1MLZDk7nm2Nbj4iKF5k8meGa1oHwnMa1wp
# 1MP7FiuQmsyuHNzqGfA4ohrW1igEM17r41
# 1MqePJDUZLLkQ2UxzDPXjxSitfBCnwqypL
# 1MryTRYddqmZx6xPZXiq81Rsgufot1xpUG
# 1MtJtD71hzHQQvPpaXuK7sA2iRM8UjTAZw
# 1N2DydVBXXLDoGsbnLPC22oUUWg5fSSan3
# 1NCbq1T9GkBfj2eW4zQFdETTHNSpF6LZzH
# 1NEJXxBYMtB2yz9ujndrjDtjGcpHHHwEsv
# 1NeUY7HXmjQdApLc42FwZcH68Xy2HXug2C
# 1NmGQYNLpLm9CLFnDPL7s1z9Cood4ZDESc
# 1Nq9D5PaxxTaPjF2yo4i8KaX3iPNph74jw
# 1NSDyu7tC1Z26Ks1ZwjAveEQZpFiZykaVv
# 1NsfGhQhfNRrAMdKdkowGa6cPAJvHNswwn
# 1NtFQixLSdjKui5P1rMpHAPTrREQGih3Rk
# 1NTmPwo2EnBwz5epsLS9bA8buTgEYMYups
# 1NzqEAosGZfH7sBer23vf1VVMPU51LTAgP
# 1P23uyHG3wpuKJwPMARNJTDRcXWDj16yGj
# 1PaDe86z63CSAVVaqzxVpbEzwn5wivot1y
# 1PhBAy6h13chnoYshwNfWKCUvUDWMVJZzD
# 1PjWwksYQrw4qAQJeTR9rQw5bqYkYZEjUR
# 1PmrZuyTrd53DqoXPazbJz9S7KDvRVvK6f
# 1PqSjLpZVeDYEytvv6KaVmQAreBPm1TGVK
# 1PQtWpKYnTGxpDuyrVK1enH6F33DWSEmfC
# 1PSkVRXhncLLbpc23gRJDwvRVF3wbV3mZk
# 1PW8efsKktW8PAShPv38ou5pR7mhbUgwbH
# 1PyS7u8qj4NF5FWnJHNpE5X1W9nWtnDsw1
# 1Q1kRgk4b8FKjxdpzjXwwt2M5Geo2penCF
# 1QBcR8KAusugNnoua4ktqbXwhgMTRGKryM
# 1QCTXbexpckGznmXczcGkNuir7fhFAWotW
# 1QLQjTCe3EniRtmZ8siothKmGSLTkjqgfV
